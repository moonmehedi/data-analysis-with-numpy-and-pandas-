# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Assignment 1: DataFrame Basics
#
# Hi there!
#
# Can you read in the transactions dataset and report on:
#
# * The number of rows and columns
# * The names of the columns
# * The datatypes of each column

# %%
# A common practice is to create a path variable to pass to read_csv
path = "../retail/transactions.csv"

transactions=pd.read_csv(path)
transactions
# Out:
#              date  store_nbr  transactions
# 0      2013-01-01         25           770
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83488 rows x 3 columns]

# %%
transactions.columns
# Out:
# Index(['date', 'store_nbr', 'transactions'], dtype='object')

# %%
transactions.dtypes
# Out:
# date            object
# store_nbr        int64
# transactions     int64
# dtype: object

# %% [markdown]
# # Assignment 2: Exploring DataFrames
#
# Hello!
#
# * Can you quickly inspect the first 5 rows of the transactions data?
#
# * Then, dive a bit more deeply into the data and check if there are any missing values.
# * What about the number of unique dates? I want to make sure we didn’t leave any out.
# * Finally, can you report the mean, median, min and max of “transactions”?  I want to check for any anomalies in our data.

# %%
transactions.head(5)
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
transactions.describe(include="all")
# Out:
#               date     store_nbr  transactions
# count        83488  83488.000000  83488.000000
# unique        1682           NaN           NaN
# top     2017-08-15           NaN           NaN
# freq            54           NaN           NaN
# mean           NaN     26.939237   1694.602158
# std            NaN     15.608204    963.286644
# min            NaN      1.000000      5.000000
# 25%            NaN     13.000000   1046.000000
# 50%            NaN     27.000000   1393.000000
# 75%            NaN     40.000000   2079.000000
# max            NaN     54.000000   8359.000000

# %%
#here top is the mode
#mean is given
#50% is the meadian
#rest given

# %% [markdown]
# # Exercise 3 - Accessing DataFrames
#
# Hi, starting to dive deeper into this data.
#
# I noticed that the first row is the only one from 2013-01-01.
#
# * Can you get me a copy of the DataFrame that excludes that row, and only includes “store_nbr” and “transactions”?
# * Also, can you report the number of unique store numbers?
# * Finally, return the total number of transactions in millions

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
transactions_new=transactions.loc[1:,["store_nbr",'transactions']]
transactions_new
# Out:
#        store_nbr  transactions
# 1              1          2111
# 2              2          2358
# 3              3          3487
# 4              4          1922
# 5              5          1903
# ...          ...           ...
# 83483         50          2804
# 83484         51          1573
# 83485         52          2255
# 83486         53           932
# 83487         54           802
#
# [83487 rows x 2 columns]

# %%
transactions_new['store_nbr'].nunique()
# Out:
# 54

# %%
transactions_new['transactions'].sum()/1000000
# Out:
# 141.478175

# %% [markdown]
# # Assignment 4: Dropping Data and Duplicates
#
# Hi there!
#
# Can you:
#
# 1. Drop the first row of data? We want it permanently removed.
# 2. Drop the date column but not in place
# 3. Return a dataframe that only includes the last row for each of the stores.
#
# Thanks!

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
transactions.drop([0],inplace=True)
transactions
# Out:
#              date  store_nbr  transactions
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# 5      2013-01-02          5          1903
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83487 rows x 3 columns]

# %%
t_new=transactions.drop("date",axis=1)
t_new
# Out:
#        store_nbr  transactions
# 1              1          2111
# 2              2          2358
# 3              3          3487
# 4              4          1922
# 5              5          1903
# ...          ...           ...
# 83483         50          2804
# 83484         51          1573
# 83485         52          2255
# 83486         53           932
# 83487         54           802
#
# [83487 rows x 2 columns]

# %%
new_transac=transactions.drop_duplicates(subset='store_nbr',keep='last')
new_transac
# Out:
#              date  store_nbr  transactions
# 83434  2017-08-15          1          1693
# 83435  2017-08-15          2          1737
# 83436  2017-08-15          3          2956
# 83437  2017-08-15          4          1283
# 83438  2017-08-15          5          1310
# 83439  2017-08-15          6          1589
# 83440  2017-08-15          7          1780
# 83441  2017-08-15          8          2621
# 83442  2017-08-15          9          2155
# 83443  2017-08-15         10          1010
# 83444  2017-08-15         11          2360
# 83445  2017-08-15         12          1096
# 83446  2017-08-15         13           842
# 83447  2017-08-15         14          1241
# 83448  2017-08-15         15          1320
# 83449  2017-08-15         16           742
# 83450  2017-08-15         17          1504
# 83451  2017-08-15         18          1343
# 83452  2017-08-15         19          1158
# 83453  2017-08-15         20          1516
# 83454  2017-08-15         21          1059
# 83455  2017-08-15         22           766
# 83456  2017-08-15         23           946
# 83457  2017-08-15         24          2138
# 83458  2017-08-15         25           849
# 83459  2017-08-15         26           534
# 83460  2017-08-15         27          1543
# 83461  2017-08-15         28          1343
# 83462  2017-08-15         29          1302
# 83463  2017-08-15         30           825
# 83464  2017-08-15         31          1360
# 83465  2017-08-15         32           615
# 83466  2017-08-15         33           919
# 83467  2017-08-15         34          2007
# 83468  2017-08-15         35           612
# 83469  2017-08-15         36          1192
# 83470  2017-08-15         37          1373
# 83471  2017-08-15         38          1445
# 83472  2017-08-15         39          1425
# 83473  2017-08-15         40          1392
# 83474  2017-08-15         41          1003
# 83475  2017-08-15         42           995
# 83476  2017-08-15         43          1482
# 83477  2017-08-15         44          3815
# 83478  2017-08-15         45          3685
# 83479  2017-08-15         46          3197
# 83480  2017-08-15         47          3581
# 83481  2017-08-15         48          2722
# 83482  2017-08-15         49          2814
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802

# %% [markdown]
# # Assignment 5: Missing Data
#
# Hello,
#
# Can you tell if any dates or prices are missing in the oil dataset?
#
# Then compare the mean of the oil series when filling in with mean vs. filling in with 0.
#
# Thanks!

# %%
oil = pd.read_csv("../retail/oil.csv")
oil
# Out:
#             date  dcoilwtico
# 0     2013-01-01         NaN
# 1     2013-01-02       93.14
# 2     2013-01-03       92.97
# 3     2013-01-04       93.12
# 4     2013-01-07       93.20
# ...          ...         ...
# 1213  2017-08-25       47.65
# 1214  2017-08-28       46.40
# 1215  2017-08-29       46.46
# 1216  2017-08-30       45.96
# 1217  2017-08-31       47.26
#
# [1218 rows x 2 columns]

# %%
oil.isna().sum()
# Out:
# date           0
# dcoilwtico    43
# dtype: int64

# %%
mean=oil.fillna(0)['dcoilwtico'].mean()
mean
# Out:
# 65.32379310344828

# %%
oil.fillna(oil['dcoilwtico'].mean())['dcoilwtico'].mean()
# Out:
# 67.71436595744682

# %% [markdown]
# # Assignment 6: Filtering DataFrames
#
# I need some quick research on store 25:
#
# * First, calculate the percentage of times ALL stores had more than 2000 transactions
# * Then, calculate the percentage of times store 25 had more than 2000 transactions, and calculate the sum of transactions on these days
# * Finally, sum the transactions for stores 25 and 3, that occurred in May or June, and had less than 2000 transactions

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922
# 5  2013-01-02          5          1903

# %%
(transactions['transactions']>2000 ).sum()/transactions.shape[0]
(transactions['transactions']>2000 ).mean()
# Out:
# 0.266808006036868

# %%
((transactions['transactions']>2000) & (transactions['store_nbr']==25)).sum()/(transactions['store_nbr']==25).sum()
transactions[(transactions['transactions']>2000) & (transactions['store_nbr']==25)]['transactions'].sum()
# Out:
# 144903

# %%
mask=((transactions['store_nbr'].isin([25,31]))&(transactions['transactions']<2000)&(transactions['date'].str[5:7].isin(['05','06'])))

transactions[mask]['transactions'].sum()
# Out:
# 644910

# %% [markdown]
# # Assignment 7: Sorting DataFrames
#
# Hi there,
# * Can you get me a dataset that includes the 5 days with the highest transactions counts? Any similarities between them?
# * Then, can you get me a dataset sorted by date from earliest to most recent, but with the highest transactions first and the lowest transactions last for each day?
# * Finally, sort the columns in reverse alphabetical order.
#
# Thanks!

# %%
transactions.head()
# Out:
#          date  store_nbr  transactions
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922
# 5  2013-01-02          5          1903

# %%
transactions.sort_values('transactions',ascending=False).head()
# Out:
#              date  store_nbr  transactions
# 52011  2015-12-23         44          8359
# 71010  2016-12-23         44          8307
# 16570  2013-12-23         44          8256
# 33700  2014-12-23         44          8120
# 16572  2013-12-23         46          8001

# %%
transactions.sort_values(['date','transactions'],ascending=[True,False])
# Out:
#              date  store_nbr  transactions
# 40     2013-01-02         46          4886
# 38     2013-01-02         44          4821
# 39     2013-01-02         45          4208
# 41     2013-01-02         47          4161
# 11     2013-01-02         11          3547
# ...           ...        ...           ...
# 83455  2017-08-15         22           766
# 83449  2017-08-15         16           742
# 83465  2017-08-15         32           615
# 83468  2017-08-15         35           612
# 83459  2017-08-15         26           534
#
# [83487 rows x 3 columns]

# %%
transactions.sort_index(axis=1,ascending=False)
# Out:
#        transactions  store_nbr        date
# 1              2111          1  2013-01-02
# 2              2358          2  2013-01-02
# 3              3487          3  2013-01-02
# 4              1922          4  2013-01-02
# 5              1903          5  2013-01-02
# ...             ...        ...         ...
# 83483          2804         50  2017-08-15
# 83484          1573         51  2017-08-15
# 83485          2255         52  2017-08-15
# 83486           932         53  2017-08-15
# 83487           802         54  2017-08-15
#
# [83487 rows x 3 columns]

# %% [markdown]
# # Assignment 8: Modifying Columns
#
# Just some quick work, but can you send me the transaction data with the columns renamed?
#
# * Rename `transactions` to `transaction_count` and `store_nbr` to `store_number`.
# * Reorder the columns so date is first, then store number, then transaction count.
#
# Thanks!

# %%
transactions.rename(columns={'transactions':'transactions_count',
'store_nbr':'store_number'},inplace=True)

# %%
transactions.reindex(labels=['date','transactions_count','store_number'],axis=1).head()
# Out:
#          date  transactions_count  store_number
# 1  2013-01-02                2111             1
# 2  2013-01-02                2358             2
# 3  2013-01-02                3487             3
# 4  2013-01-02                1922             4
# 5  2013-01-02                1903             5

# %% [markdown]
# # Assignment 9: Column Creation
#
# Just some quick work, but can you send me the transaction data with the columns renamed?
#
# * Create a `pct_to_target` column that divides transactions by 2500.
# * Then, create a `met_target` column that returns True if `pct_to_target` is greater than or equal to 1.
# * Next, create a `bonus_payable` column that equals 100 if `met_target` is True, and 0 if not. Then sum the bonus payable column.
# * Finally, create columns for month and day of week as integers. There is some helper code for these dateparts below.
#
#
#
# Thanks!

# %%
transactions.head()
# Out:
#          date  store_number  transactions_count
# 1  2013-01-02             1                2111
# 2  2013-01-02             2                2358
# 3  2013-01-02             3                3487
# 4  2013-01-02             4                1922
# 5  2013-01-02             5                1903

# %%
transactions['pct to target']=transactions['transactions_count']/2500
transactions
# Out:
#              date  store_number  transactions_count  pct to target
# 1      2013-01-02             1                2111         0.8444
# 2      2013-01-02             2                2358         0.9432
# 3      2013-01-02             3                3487         1.3948
# 4      2013-01-02             4                1922         0.7688
# 5      2013-01-02             5                1903         0.7612
# ...           ...           ...                 ...            ...
# 83483  2017-08-15            50                2804         1.1216
# 83484  2017-08-15            51                1573         0.6292
# 83485  2017-08-15            52                2255         0.9020
# 83486  2017-08-15            53                 932         0.3728
# 83487  2017-08-15            54                 802         0.3208
#
# [83487 rows x 4 columns]

# %%
transactions['mer target']=transactions['pct to target']>=1
transactions['bonous payable']=(100 * (transactions['mer target']))
transactions
# Out:
#              date  store_number  transactions_count  pct to target  \
# 1      2013-01-02             1                2111         0.8444
# 2      2013-01-02             2                2358         0.9432
# 3      2013-01-02             3                3487         1.3948
# 4      2013-01-02             4                1922         0.7688
# 5      2013-01-02             5                1903         0.7612
# ...           ...           ...                 ...            ...
# 83483  2017-08-15            50                2804         1.1216
# 83484  2017-08-15            51                1573         0.6292
# 83485  2017-08-15            52                2255         0.9020
# 83486  2017-08-15            53                 932         0.3728
# 83487  2017-08-15            54                 802         0.3208
#
#        mer target  bonous payable
# 1           False               0
# 2           False               0
# 3            True             100
# 4           False               0
# 5           False               0
# ...           ...             ...
# 83483        True             100
# 83484       False               0
# 83485       False               0
# 83486       False               0
# 83487       False               0
#
# [83487 rows x 6 columns]

# %%
#date columns

transactions['date']=pd.to_datetime(transactions['date'])
transactions['month']=transactions['date'].dt.month
transactions['day of week']=transactions['date'].dt.day_of_week
transactions
# Out:
#             date  store_number  transactions_count  pct to target  mer target  \
# 1     2013-01-02             1                2111         0.8444       False
# 2     2013-01-02             2                2358         0.9432       False
# 3     2013-01-02             3                3487         1.3948        True
# 4     2013-01-02             4                1922         0.7688       False
# 5     2013-01-02             5                1903         0.7612       False
# ...          ...           ...                 ...            ...         ...
# 83483 2017-08-15            50                2804         1.1216        True
# 83484 2017-08-15            51                1573         0.6292       False
# 83485 2017-08-15            52                2255         0.9020       False
# 83486 2017-08-15            53                 932         0.3728       False
# 83487 2017-08-15            54                 802         0.3208       False
#
#        bonous payable  month  day of week
# 1                   0      1            2
# 2                   0      1            2
# 3                 100      1            2
# 4                   0      1            2
# 5                   0      1            2
# ...               ...    ...          ...
# 83483             100      8            1
# 83484               0      8            1
# 83485               0      8            1
# 83486               0      8            1
# 83487               0      8            1
#
# [83487 rows x 8 columns]

# %% [markdown]
# # Assignment 10: np.select
#
# Hi there! I need a few columns created.
#
# 1. Create a ‘seasonal_bonus’ column that applies to these dates:
#     * All days in December (month = 12)
#     * Sundays (day_of_week = 6) in May (month = 5)
#     * Mondays (day_of_week = 0) in July (month = 7)
# 2. Call the December bonus ‘Holiday Bonus’, the May bonus ‘Corporate Month’, and the July bonus ‘Summer Special’. If no bonus applies, the column should display ‘None’.
# 3. Finally, calculate the total bonus owed at $100 per day.
#
# Thanks!

# %%
transactions.head()
# Out:
#         date  store_number  transactions_count  pct to target  mer target  \
# 1 2013-01-02             1                2111         0.8444       False
# 2 2013-01-02             2                2358         0.9432       False
# 3 2013-01-02             3                3487         1.3948        True
# 4 2013-01-02             4                1922         0.7688       False
# 5 2013-01-02             5                1903         0.7612       False
#
#    bonous payable  month  day of week
# 1               0      1            2
# 2               0      1            2
# 3             100      1            2
# 4               0      1            2
# 5               0      1            2

# %%
conditions=[
    (transactions['date'].dt.month==12),
    (transactions['date'].dt.month==5)&(transactions['date'].dt.day_of_week==6),
    (transactions['date'].dt.month==7)&(transactions['date'].dt.day_of_week==0),
]

choices=['holiday bonous','corporate month','summer special']

transactions['seasonal bonous']=np.select(conditions,choices,'none')
transactions['bonus owned']=(transactions['seasonal bonous']!='none')*100
transactions
# Out:
#             date  store_number  transactions_count  pct to target  mer target  \
# 1     2013-01-02             1                2111         0.8444       False
# 2     2013-01-02             2                2358         0.9432       False
# 3     2013-01-02             3                3487         1.3948        True
# 4     2013-01-02             4                1922         0.7688       False
# 5     2013-01-02             5                1903         0.7612       False
# ...          ...           ...                 ...            ...         ...
# 83483 2017-08-15            50                2804         1.1216        True
# 83484 2017-08-15            51                1573         0.6292       False
# 83485 2017-08-15            52                2255         0.9020       False
# 83486 2017-08-15            53                 932         0.3728       False
# 83487 2017-08-15            54                 802         0.3208       False
#
#        bonous payable  month  day of week seasonal bonous  bonus owned
# 1                   0      1            2            none            0
# 2                   0      1            2            none            0
# 3                 100      1            2            none            0
# 4                   0      1            2            none            0
# 5                   0      1            2            none            0
# ...               ...    ...          ...             ...          ...
# 83483             100      8            1            none            0
# 83484               0      8            1            none            0
# 83485               0      8            1            none            0
# 83486               0      8            1            none            0
# 83487               0      8            1            none            0
#
# [83487 rows x 10 columns]

# %% [markdown]
# transactions['seasonal bonous']=np.select(conditions,choices,'none')
# transactions['bonus owned']=(transactions['seasonal bonous']!='none')*100
# transactions['bonus owned'].sum()

# %%
transactions['bonus owned'].sum()
# Out:
# 822900

# %% [markdown]
# # Assignment 11: Assign
#
# * Drop the columns that have been created so far (keep only date, store_number, and transaction count), and recreate them using the assign method.
# * Then sum the seasonal bonus owed once again to make sure the numbers are correct.

# %%
# Drop columns we created in prior exercises

# %%
# Create same columns with assign

# %% [markdown]
# # Assignment 12: Memory Optimization
#
# Reduce the memory usage of the transactions DataFrame to below 5MB.

# %%
transactions.head()
# Out:
#         date  store_number  transactions_count  pct to target  mer target  \
# 1 2013-01-02             1                2111         0.8444       False
# 2 2013-01-02             2                2358         0.9432       False
# 3 2013-01-02             3                3487         1.3948        True
# 4 2013-01-02             4                1922         0.7688       False
# 5 2013-01-02             5                1903         0.7612       False
#
#    bonous payable  month  day of week seasonal bonous  bonus owned
# 1               0      1            2            none            0
# 2               0      1            2            none            0
# 3             100      1            2            none            0
# 4               0      1            2            none            0
# 5               0      1            2            none            0

# %%
transactions.info(memory_usage="deep")
transactions['bonus owned'].max()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83487 entries, 1 to 83487
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                83487 non-null  datetime64[ns]
#  1   store_number        83487 non-null  int64
#  2   transactions_count  83487 non-null  int64
#  3   pct to target       83487 non-null  float64
#  4   mer target          83487 non-null  bool
#  5   bonous payable      83487 non-null  int32
#  6   month               83487 non-null  int32
#  7   day of week         83487 non-null  int32
#  8   seasonal bonous     83487 non-null  object
#  9   bonus owned         83487 non-null  int32
# dtypes: bool(1), datetime64[ns](1), float64(1), int32(4), int64(2), object(1)
# memory usage: 8.8 MB
# 100

# %%
transactions=transactions.astype({'store_number':'int8','transactions_count':'int16','pct to target':'float16','bonous payable':'int8',"month":'int8','day of week':'int8','seasonal bonous':'category','bonus owned':'int8'})
transactions.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83487 entries, 1 to 83487
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                83487 non-null  datetime64[ns]
#  1   store_number        83487 non-null  int8
#  2   transactions_count  83487 non-null  int16
#  3   pct to target       83487 non-null  float16
#  4   mer target          83487 non-null  bool
#  5   bonous payable      83487 non-null  int8
#  6   month               83487 non-null  int8
#  7   day of week         83487 non-null  int8
#  8   seasonal bonous     83487 non-null  category
#  9   bonus owned         83487 non-null  int8
# dtypes: bool(1), category(1), datetime64[ns](1), float16(1), int16(1), int8(5)
# memory usage: 1.5 MB
